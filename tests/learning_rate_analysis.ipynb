# %% [markdown]
# <h1>FFNN From Scratch</h1>
# <h2>Learning Rate Analysis</h2>

# %% [markdown]
# <h3>Configure Root</h3>

# %%
import sys
from pathlib import Path as path

root = path.cwd().parent
if str(root) not in sys.path:
    sys.path.insert(0, str(root))

# %% [markdown]
# <h3>Import Library</h3>

# %%
import numpy as np
import matplotlib.pyplot as plt
from src.model.layers import FFNN
from src.model.activations import Activation
from src.model.loss import Loss
from src.model.optimizer import GradientDescent
from src.model.initializer import Initializer
from src.utils.data_loader import DataLoader
from src.utils.visualization import Visualizer

# %% [markdown]
# <h3>Importing Data</h3>

# %%
loader = DataLoader('../data/datasetml_2026.csv')
loader.load()
loader.eda()
loader.split(train_ratio=0.8, random_seed=42)
loader.preprocess()
loader.split_val(val_size=0.2, random_state=42)

X_train, y_train = loader.get_train()
X_val, y_val   = loader.get_val()
X_test, y_test  = loader.get_test()

X_train = np.asarray(X_train,dtype=np.float64)
X_val = np.asarray(X_val,dtype=np.float64)
X_test = np.asarray(X_test,dtype=np.float64)
y_train = np.asarray(y_train,dtype=np.float64)
y_val = np.asarray(y_val,dtype=np.float64)
y_test = np.asarray(y_test,dtype=np.float64)

INPUT_DIM = X_train.shape[1]
print(f'Input dim: {INPUT_DIM}')
print(f'Train: {X_train.shape}')
print(f'Val: {X_val.shape}')
print(f'Test: {X_test.shape}')
# Out:
# [DataLoader] Berhasil memuat 10000 baris dan 12 kolom dari '../data/datasetml_2026.csv'
#
# [DataLoader] Kolom: ['cgpa', 'backlogs', 'college_tier', 'country', 'university_ranking_band', 'internship_count', 'aptitude_score', 'communication_score', 'specialization', 'industry', 'internship_quality_score', 'placement_status']
#
# =================================================================
#                           Head Dataset
# =================================================================
#        cgpa  backlogs college_tier country university_ranking_band  \
# 0  7.397371         1       Tier 2  Canada                 100-300
# 1  6.889389         0       Tier 3      UK                    300+
# 2  7.518151         0       Tier 1      UK                 100-300
# 3  8.218424         0       Tier 2      UK                 100-300
# 4  6.812677         1       Tier 2     USA                 100-300
#
#    internship_count  aptitude_score  communication_score specialization  \
# 0                 2       53.574150            64.177062   Data Science
# 1                 1       60.687750            88.346052   Data Science
# 2                 2       64.568750            69.493171  Cybersecurity
# 3                 3       73.461500            78.204854          AI/ML
# 4                 4       86.518121            44.680881   Data Science
#
#      industry  internship_quality_score placement_status
# 0  Consulting                  5.481450           Placed
# 1  Consulting                  4.625099           Placed
# 2  Healthcare                  5.227939           Placed
# 3        Tech                  5.150674           Placed
# 4  Consulting                  3.888824           Placed
# =================================================================
#                       Datatypes Dataset===
# =================================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cgpa                      10000 non-null  float64
#  1   backlogs                  10000 non-null  int64
#  2   college_tier              10000 non-null  object
#  3   country                   10000 non-null  object
#  4   university_ranking_band   10000 non-null  object
#  5   internship_count          10000 non-null  int64
#  6   aptitude_score            10000 non-null  float64
#  7   communication_score       10000 non-null  float64
#  8   specialization            10000 non-null  object
#  9   industry                  10000 non-null  object
#  10  internship_quality_score  10000 non-null  float64
#  11  placement_status          10000 non-null  object
# dtypes: float64(4), int64(2), object(6)
# memory usage: 937.6+ KB
# None
# =================================================================
#                      Informasi Missing Data
# =================================================================
# cgpa                        0
# backlogs                    0
# college_tier                0
# country                     0
# university_ranking_band     0
# internship_count            0
# aptitude_score              0
# communication_score         0
# specialization              0
# industry                    0
# internship_quality_score    0
# placement_status            0
# dtype: int64
# =================================================================
#                     Informasi Duplikasi Data
# =================================================================
# np.int64(0)
# =================================================================
#                   Informasi Outlier (Metode IQR
# =================================================================
# cgpa: 83 outliers
# backlogs: 29 outliers
# internship_count: 662 outliers
# aptitude_score: 0 outliers
# communication_score: 0 outliers
# internship_quality_score: 36 outliers
#
# =================================================================
#                    Informasi Distribusi Target
# =================================================================
# placement_status
# Placed        6153
# Not Placed    3847
# Name: count, dtype: int64
# placement_status
# Placed        0.615
# Not Placed    0.385
# Name: proportion, dtype: float64
# [DataLoader] Data di-split: 8000 Train, 2000 Test
#
#
#
# =================================================================
#                Informasi Outlier Setelah Clipping
# =================================================================
# cgpa: 0 outliers
# backlogs: 0 outliers
# internship_count: 0 outliers
# aptitude_score: 0 outliers
# communication_score: 0 outliers
# internship_quality_score: 0 outliers
# [DataLoader] Preprocessing selesai.
# [DataLoader] X_train : (6400, 21) | y_train : (6400,)
# [DataLoader] X_val   : (1600, 21)   | y_val   : (1600,)
# Input dim: 21
# Train: (6400, 21)
# Val: (1600, 21)
# Test: (2000, 21)

# %% [markdown]
# <h3>Initialize Model</h3>

# %%
model1 = FFNN(
    input_dim=INPUT_DIM, 
    hidden_dim=[128, 64], 
    output_dim=1, 
    hidden_activation='relu', 
    output_activation='sigmoid', 
    loss_name='bce', 
    init_method='he', 
    seed=42
)

model2 = FFNN(
    input_dim=INPUT_DIM, 
    hidden_dim=[128, 64], 
    output_dim=1, 
    hidden_activation='relu', 
    output_activation='sigmoid', 
    loss_name='bce', 
    init_method='he', 
    seed=42
)

model3 = FFNN(
    input_dim=INPUT_DIM, 
    hidden_dim=[128, 64], 
    output_dim=1, 
    hidden_activation='relu', 
    output_activation='sigmoid', 
    loss_name='bce', 
    init_method='he', 
    seed=42
)
# Out:
# [FFNN] architecture initialized with: 21 -> 128 -> 64 -> 1
# [FFNN] hidden activation: relu
# [FFNN] output activation: sigmoid
# [FFNN] loss function: bce
# [FFNN] weight init: he, seed=42
# [FFNN] architecture initialized with: 21 -> 128 -> 64 -> 1
# [FFNN] hidden activation: relu
# [FFNN] output activation: sigmoid
# [FFNN] loss function: bce
# [FFNN] weight init: he, seed=42
# [FFNN] architecture initialized with: 21 -> 128 -> 64 -> 1
# [FFNN] hidden activation: relu
# [FFNN] output activation: sigmoid
# [FFNN] loss function: bce
# [FFNN] weight init: he, seed=42

# %% [markdown]
# <h3>Train Models</h3>

# %%
optimizer1 = GradientDescent(lr=0.1)
optimizer2 = GradientDescent(lr=0.01)
optimizer3 = GradientDescent(lr=0.001)
viz = Visualizer()

epochs = 50
batch_size = 32

models = [
    ('LR = 0.1', model1, optimizer1),
    ('LR = 0.01', model2, optimizer2),
    ('LR = 0.001', model3, optimizer3)
]

results = {}
for name, model, optimizer, in models:
    viz.print_section_term(f"Training {name}")
    for epoch in range(1, epochs + 1):
        metrics = model.train_epoch(
            X_train, y_train,
            optimizer=optimizer,
            batch_size=batch_size,
            x_val=X_val,
            y_val=y_val,
        )
        print(f"Epoch {epoch:03d}/{epochs}"
              + f"Train loss: {metrics['train_loss']:.4f}, acc: {metrics['train_acc']:.4f}"
              + f"Validation loss: {metrics['val_loss']:.4f}, acc: {metrics['val_acc']:.4f}")
    results[name] = {
        'model'  : model,
        'history': model.get_training_history(),
    }

print('\n=== Test Accuracy ===')
for name, model in results.items():
    y_pred = model['model'].predict(X_test)
    acc    = float(np.mean(y_pred == y_test.ravel()))
    print(f'  {name:12s}  |  Test Acc: {acc:.4f} ({acc*100:.2f}%)')
# Out:
# =================================================================
#                         Training LR = 0.1
# =================================================================
# Epoch 001/50Train loss: 0.5332, acc: 0.7522Validation loss: 0.4907, acc: 0.7575
# Epoch 002/50Train loss: 0.4998, acc: 0.7561Validation loss: 0.4857, acc: 0.7656
# Epoch 003/50Train loss: 0.4928, acc: 0.7616Validation loss: 0.4814, acc: 0.7612
# Epoch 004/50Train loss: 0.4900, acc: 0.7619Validation loss: 0.4835, acc: 0.7612
# Epoch 005/50Train loss: 0.4882, acc: 0.7680Validation loss: 0.4788, acc: 0.7631
# Epoch 006/50Train loss: 0.4861, acc: 0.7703Validation loss: 0.4781, acc: 0.7694
# Epoch 007/50Train loss: 0.4850, acc: 0.7684Validation loss: 0.4822, acc: 0.7644
# Epoch 008/50Train loss: 0.4826, acc: 0.7720Validation loss: 0.4811, acc: 0.7700
# Epoch 009/50Train loss: 0.4783, acc: 0.7734Validation loss: 0.4827, acc: 0.7650
# Epoch 010/50Train loss: 0.4775, acc: 0.7719Validation loss: 0.4829, acc: 0.7656
# Epoch 011/50Train loss: 0.4757, acc: 0.7622Validation loss: 0.4999, acc: 0.7562
# Epoch 012/50Train loss: 0.4726, acc: 0.7750Validation loss: 0.4870, acc: 0.7694
# Epoch 013/50Train loss: 0.4704, acc: 0.7725Validation loss: 0.4871, acc: 0.7675
# Epoch 014/50Train loss: 0.4695, acc: 0.7809Validation loss: 0.4830, acc: 0.7656
# Epoch 015/50Train loss: 0.4649, acc: 0.7788Validation loss: 0.4849, acc: 0.7662
# Epoch 016/50Train loss: 0.4646, acc: 0.7780Validation loss: 0.4856, acc: 0.7625
# Epoch 017/50Train loss: 0.4619, acc: 0.7812Validation loss: 0.4826, acc: 0.7675
# Epoch 018/50Train loss: 0.4593, acc: 0.7819Validation loss: 0.4890, acc: 0.7631
# Epoch 019/50Train loss: 0.4587, acc: 0.7891Validation loss: 0.4850, acc: 0.7631
# Epoch 020/50Train loss: 0.4542, acc: 0.7880Validation loss: 0.4867, acc: 0.7631
# Epoch 021/50Train loss: 0.4520, acc: 0.7881Validation loss: 0.4937, acc: 0.7562
# Epoch 022/50Train loss: 0.4501, acc: 0.7898Validation loss: 0.4887, acc: 0.7575
# Epoch 023/50Train loss: 0.4465, acc: 0.7834Validation loss: 0.5043, acc: 0.7606
# Epoch 024/50Train loss: 0.4428, acc: 0.7958Validation loss: 0.4978, acc: 0.7581
# Epoch 025/50Train loss: 0.4420, acc: 0.7994Validation loss: 0.4930, acc: 0.7619
# Epoch 026/50Train loss: 0.4370, acc: 0.7977Validation loss: 0.4978, acc: 0.7569
# Epoch 027/50Train loss: 0.4335, acc: 0.7928Validation loss: 0.5123, acc: 0.7475
# Epoch 028/50Train loss: 0.4313, acc: 0.7922Validation loss: 0.5171, acc: 0.7538
# Epoch 027/50Train loss: 0.4996, acc: 0.7547Validation loss: 0.4882, acc: 0.7644
# Epoch 028/50Train loss: 0.4990, acc: 0.7552Validation loss: 0.4880, acc: 0.7631
# Epoch 029/50Train loss: 0.4986, acc: 0.7553Validation loss: 0.4875, acc: 0.7638
# Epoch 030/50Train loss: 0.4980, acc: 0.7544Validation loss: 0.4874, acc: 0.7619
# Epoch 031/50Train loss: 0.4975, acc: 0.7558Validation loss: 0.4868, acc: 0.7631
# Epoch 032/50Train loss: 0.4973, acc: 0.7559Validation loss: 0.4866, acc: 0.7638
# Epoch 033/50Train loss: 0.4968, acc: 0.7553Validation loss: 0.4864, acc: 0.7631
# Epoch 034/50Train loss: 0.4965, acc: 0.7567Validation loss: 0.4862, acc: 0.7625
# Epoch 035/50Train loss: 0.4962, acc: 0.7577Validation loss: 0.4860, acc: 0.7625
# Epoch 036/50Train loss: 0.4959, acc: 0.7569Validation loss: 0.4858, acc: 0.7631
# Epoch 037/50Train loss: 0.4955, acc: 0.7578Validation loss: 0.4856, acc: 0.7625
# Epoch 038/50Train loss: 0.4952, acc: 0.7578Validation loss: 0.4856, acc: 0.7619
# Epoch 039/50Train loss: 0.4949, acc: 0.7577Validation loss: 0.4853, acc: 0.7638
# Epoch 040/50Train loss: 0.4947, acc: 0.7584Validation loss: 0.4852, acc: 0.7619
# Epoch 041/50Train loss: 0.4944, acc: 0.7592Validation loss: 0.4850, acc: 0.7644
# Epoch 042/50Train loss: 0.4943, acc: 0.7575Validation loss: 0.4849, acc: 0.7638
# Epoch 043/50Train loss: 0.4940, acc: 0.7581Validation loss: 0.4849, acc: 0.7625
# Epoch 044/50Train loss: 0.4938, acc: 0.7577Validation loss: 0.4847, acc: 0.7631
# Epoch 045/50Train loss: 0.4937, acc: 0.7586Validation loss: 0.4846, acc: 0.7638
# Epoch 046/50Train loss: 0.4935, acc: 0.7573Validation loss: 0.4845, acc: 0.7631
# Epoch 047/50Train loss: 0.4932, acc: 0.7584Validation loss: 0.4845, acc: 0.7631
# Epoch 048/50Train loss: 0.4931, acc: 0.7573Validation loss: 0.4843, acc: 0.7638
# Epoch 049/50Train loss: 0.4929, acc: 0.7584Validation loss: 0.4842, acc: 0.7619
# Epoch 050/50Train loss: 0.4928, acc: 0.7581Validation loss: 0.4841, acc: 0.7638
#
# === Test Accuracy ===
#   LR = 0.1      |  Test Acc: 0.6960 (69.60%)
#   LR = 0.01     |  Test Acc: 0.7445 (74.45%)
#   LR = 0.001    |  Test Acc: 0.7400 (74.00%)

# %% [markdown]
# ## Plot Loss Curve

# %%
viz.plot_comparison(
    results     = results,
    mode        = 'loss',
    save_prefix = '../results/lr',
)
# Out:
# [Visualizer] saved in ../results/lr_loss.png

# %% [markdown]
# ## Plot Weight Distribution

# %%
viz.plot_comparison(
    results     = results,
    mode        = 'weights',
    save_prefix = '../results/lr',
)
# Out:
# [Visualizer] saved in ../results/lr_weights.png

# %% [markdown]
# ## Plot : Gradient Distribution

# %%
viz.plot_comparison(
    results     = results,
    mode        = 'grads',
    save_prefix = '../results/lr',
    x_ref       = X_test,
    y_ref       = y_test,
)
# Out:
# [Visualizer] saved in ../results/lr_grads.png
